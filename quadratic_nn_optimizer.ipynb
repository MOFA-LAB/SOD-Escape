# %% [markdown]
# **Author:** Tianqi Shen & Ziye Ma & GPT-4o
#
# **Date:** 21 June 2026

# %% [markdown]
# # Numerical Experiments of SOD-Escape Mechanism (Line-Search Version)
# ## Quadratic Neural Network on Iris Binary Classification
#
# Recall that optimizing a Burer-Monteiro (BM) factorized matrix sensing problem is equivalent to training a two-layer quadratic neural network (https://arxiv.org/abs/1712.09203).
# This notebook studies the optimization behavior of a one-hidden-layer quadratic neural network on binary classification tasks constructed from the Iris dataset. We allow any pair of Iris classes to be selected, namely Setosa, Versicolor, and Virginica.
#
# The model considered in this notebook is a quadratic neural network of the form
# $$
#     \hat{y}_i
#     =
#     \sum_{j=1}^{r}
#     \left(
#     u_j^\top x_i
#     \right)^2
#     =
#     x_i^\top U U^\top x_i,
# $$
# where $x_i \in \mathbb{R}^d$ denotes the input feature vector, optionally augmented with a bias coordinate, and $U \in \mathbb{R}^{d \times r}$ is the trainable factor matrix. The parameter $r$ controls the rank, or equivalently the hidden width, of the quadratic model.
#
# The empirical objective is the mean squared error
# $$
#     h(U)
#     =
#     \frac{1}{2N}
#     \sum_{i=1}^{N}
#     \left(
#     \hat{y}_i - y_i
#     \right)^2
#     +
#     \frac{\lambda}{2}
#     \|U\|_F^2,
# $$
# where $N$ is the number of training samples, $y_i$ is the binary target label, and $\lambda \geq 0$ is an optional weight-decay parameter.
#
# The main focus of this notebook is to evaluate a structured line-search mechanism based on second-order directional information, referred to as SOD line search. During training, full-batch gradient descent is first applied. When progress stalls according to a window-based relative loss decrease criterion, the algorithm constructs structured search directions from the matrix-space gradient
# $$
#     G
#     =
#     \frac{1}{N}
#     \sum_{i=1}^{N}
#     \left(
#     \hat{y}_i - y_i
#     \right)
#     x_i x_i^\top.
# $$
#
# In particular, the SOD directions are constructed using the minimum eigenvector of $G$, together with the smallest singular directions of the current factor matrix $U$ (i.e., $\sigma_r$). A deterministic line search is then performed along the following directions to determine whether a loss-decreasing update can be found:
# - $u_d q_r^\top$, where $(\lambda_d,u_d)$ are the eigenpair of $G$;
# - $\sum_{i=1}^{N}\left[x_i^\top \left( u_d v_r^\top + v_r u_d^\top \right) x_i\right] x_i x_i^\top$, where $(\sigma_r,v_r,q_r)$ are the singular value-vector triples of $U$.
#
# For comparison, this notebook also includes several baseline optimization methods:
#
# - full-batch gradient descent only;
# - gradient descent with SOD-guided structured line search;
# - sgd;
# - adam.
#
# The experiments report training loss, test loss, training accuracy, test accuracy, and the accepted line-search events. This allows us to examine whether SOD-guided line search can help escape flat or stalled regions of the nonconvex optimization landscape more effectively than standard gradient-based or random search baselines.

# %%
# %matplotlib inline
#import matplotlib_inline   # setup output image format, do not use 'svg' if need 'pdf' output
#matplotlib_inline.backend_inline.set_matplotlib_formats('svg')
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 300
import matplotlib
import numpy as np
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load Hyper-parameters and MS Problem

# %%
# Load hyper-parameters
class Args:
    class_pair = (1, 2)  # 0: Setosa 1: Versicolor 2: Virginica
    # "zero_one": negative class -> 0, positive class -> 1
    # "smooth":   negative class -> 0.1, positive class -> 1.0
    label_mode = "zero_one"
    test_size = 0.5
    seed = 0  # 10086 is also ok
    add_bias = True
    r = 2
    init_scale = 1e-8
    weight_decay = 0.0
    max_iters = 15000
    # Learning-rates
    lr_dict = {"gd": 0.01, "gd_sod": 0.01, "sgd": 0.002, "adam": 0.002}
    method = "compare"  # "gd", "gd_sod", "sgd", "adam", or "compare"
    batch_size = 8  # mini-batch settings for SGD and Adam
    # Adam hyper-parameters
    adam_beta1 = 0.9
    adam_beta2 = 0.999
    adam_eps = 1e-8
    # Stall detection
    stall_window = 200
    stall_tol = 1e-7
    min_iters_before_sod = 500
    sod_cooldown = 200
    accept_tol = 1e-5
    # Line search grid
    alpha_min_exp = -6
    alpha_max_exp = 2
    alpha_points_per_decade = 20
args = Args()
np.random.seed(args.seed)

# %% [markdown]
# ### Functional helpers for loading and preprocessing dataset

# %%
def load_iris_binary(class_pair=(1, 2), test_size=0.3, seed=0, add_bias=True, label_mode="zero_one",):
    """
    Load Iris dataset and keep only two selected classes.

    sklearn target labels:
        0: Setosa
        1: Versicolor
        2: Virginica

    Parameters
    ----------
    class_pair : tuple of int
        The two classes to keep, e.g.
            (0, 1): Setosa vs Versicolor
            (0, 2): Setosa vs Virginica
            (1, 2): Versicolor vs Virginica

        class_pair[0] will be mapped to label 0.
        class_pair[1] will be mapped to label 1.

    test_size : float
        Test split ratio.

    seed : int
        Random seed for train/test split.

    add_bias : bool
        If True, append one bias coordinate to each x.

    label_mode : str
        "zero_one":
            class_pair[0] -> 0, class_pair[1] -> 1.
        "smooth":
            class_pair[0] -> 0.1, class_pair[1] -> 1.0.

    Returns
    -------
    X_train, y_train, X_test, y_test, meta
    """

    iris = load_iris()
    X = iris.data.astype(float)
    y_raw = iris.target.astype(int)

    target_names = iris.target_names
    class_0, class_1 = class_pair
    valid_classes = {0, 1, 2}

    if len(class_pair) != 2:
        raise ValueError("class_pair must contain exactly two class labels.")
    if class_0 not in valid_classes or class_1 not in valid_classes:
        raise ValueError("Iris class labels must be selected from {0, 1, 2}.")
    if class_0 == class_1:
        raise ValueError("class_pair must contain two different classes.")

    # Keep selected two classes.
    mask = (y_raw == class_0) | (y_raw == class_1)
    X = X[mask]
    y_raw = y_raw[mask]

    # Binary labels:  class_0 -> 0    class_1 -> 1
    y = (y_raw == class_1).astype(float)

    if label_mode == "smooth":
        y = 0.1 + 0.9 * y
    elif label_mode == "zero_one":
        pass
    else:
        raise ValueError("label_mode must be either 'zero_one' or 'smooth'.")

    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed, stratify=y,)

    # Standardize using training statistics only.
    mu = X_train.mean(axis=0, keepdims=True)
    std = X_train.std(axis=0, keepdims=True) + 1e-12
    X_train = (X_train - mu) / std
    X_test = (X_test - mu) / std

    if add_bias:
        X_train = np.concatenate([X_train, np.ones((X_train.shape[0], 1))], axis=1,)
        X_test = np.concatenate([X_test, np.ones((X_test.shape[0], 1))], axis=1,)

    meta = {
        "class_pair": class_pair,
        "negative_class": class_0,
        "positive_class": class_1,
        "negative_class_name": target_names[class_0],
        "positive_class_name": target_names[class_1],
        "feature_names": iris.feature_names,
        "target_names": target_names,
        "mu": mu,
        "std": std,
        "add_bias": add_bias,
        "label_mode": label_mode,
    }

    return X_train, y_train, X_test, y_test, meta

X_train, y_train, X_test, y_test, meta = load_iris_binary(class_pair=args.class_pair, test_size=args.test_size,
                                                          seed=args.seed, add_bias=args.add_bias, label_mode=args.label_mode,)

print("Data loaded:")
print(f"  Class pair: {meta['class_pair']}")
print(f"  Negative class: {meta['negative_class']} ({meta['negative_class_name']})")
print(f"  Positive class: {meta['positive_class']} ({meta['positive_class_name']})")
print(f"  X_train shape: {X_train.shape}")
print(f"  X_test  shape: {X_test.shape}")
print(f"  y_train distribution: mean={y_train.mean():.3f}")
print(f"  y_test  distribution: mean={y_test.mean():.3f}")
print(f"  model rank r: {args.r}")
# Out:
# Data loaded:
#   Class pair: (1, 2)
#   Negative class: 1 (versicolor)
#   Positive class: 2 (virginica)
#   X_train shape: (50, 5)
#   X_test  shape: (50, 5)
#   y_train distribution: mean=0.500
#   y_test  distribution: mean=0.500
#   model rank r: 2

# %% [markdown]
# ### Functional helpers for quadratic network

# %%
def predict(U, X):
    """
    Predict using one-hidden-layer quadratic network.
    y_hat_i = sum_j (x_i^T u_j)^2

    Parameters
    ----------
    U : ndarray, shape (d, r)
    X : ndarray, shape (N, d)

    Returns
    -------
    y_hat : ndarray, shape (N,)
    """

    Z = X @ U
    y_hat = np.sum(Z ** 2, axis=1)
    return y_hat

def loss(U, X, y, weight_decay=0.0):
    """
    MSE objective: h(U) = 1/(2N) ||predict(U, X) - y||^2 + weight_decay / 2 * ||U||_F^2
    """

    residual = predict(U, X) - y
    data_loss = 0.5 * np.mean(residual ** 2)
    reg_loss = 0.5 * weight_decay * np.sum(U ** 2)
    return data_loss + reg_loss

def accuracy(U, X, y, threshold=0.5):
    """
    Classification accuracy.
    For zero-one labels, predict class 1 if y_hat >= threshold.
    """

    y_hat = predict(U, X)
    y_pred = (y_hat >= threshold).astype(float)

    # If labels are smoothed, convert them back to {0,1}.
    y_true = (y >= 0.5).astype(float)

    return np.mean(y_pred == y_true)

def matrix_gradient_G(U, X, y):
    """
    Compute matrix-space gradient G = 1/N sum_i residual_i x_i x_i^T
    where residual_i = x_i^T U U^T x_i - y_i.
    Then the factor gradient is grad_U = 2 G U.
    """

    N, d = X.shape
    residual = predict(U, X) - y

    # Efficient vectorized formula: G = X^T diag(residual) X / N
    G = (X.T * residual) @ X / N

    # Symmetrize for numerical stability.
    G = 0.5 * (G + G.T)

    return G

def grad_U(U, X, y, weight_decay=0.0):
    """
    Gradient of h(U): grad h(U) = 2 G U + weight_decay * U.
    """

    G = matrix_gradient_G(U, X, y)
    return 2.0 * G @ U + weight_decay * U

def grad_U_batch(U, X, y, batch_idx, weight_decay=0.0):
    """
    Mini-batch gradient of h(U).

    Parameters
    ----------
    U : ndarray, shape (d, r)
    X : ndarray, shape (N, d)
    y : ndarray, shape (N,)
    batch_idx : ndarray
        Indices of mini-batch samples.

    Returns
    -------
    grad : ndarray, shape (d, r)
    """

    Xb = X[batch_idx]
    yb = y[batch_idx]

    return grad_U(U, Xb, yb, weight_decay=weight_decay)

# %% [markdown]
# ### Functional helper for SOD-Escape

# %%
def AstarA(B, X):
    """
    Compute A^* A(B) for sensing matrices A_i = x_i x_i^T:
        A^* A(B) = 1/N sum_i <x_i x_i^T, B> x_i x_i^T.
    Since
        <x_i x_i^T, B> = x_i^T B x_i,
    we can compute it vectorized.

    Parameters
    ----------
    B : ndarray, shape (d, d)
    X : ndarray, shape (N, d)

    Returns
    -------
    E : ndarray, shape (d, d)
    """

    N, d = X.shape

    coeff = np.einsum("ni,ij,nj->n", X, B, X)
    E = (X.T * coeff) @ X / N

    E = 0.5 * (E + E.T)
    return E

def sod_directions(U, X, y, normalize=True):
    """
    Construct SOD beta and gamma directions.

    Inputs
    ------
    U : ndarray, shape (d, r)
        Current factor.
    X : ndarray, shape (N, d)
        Training features with bias.
    y : ndarray, shape (N,)
        Training labels.

    Returns
    -------
    info : dict
        Contains:
            D_beta, D_gamma, lambda_min, sigma_min, u_min, v_min, q_min, G, E

    Definition
    ----------
    Let G = 1/N sum_i residual_i x_i x_i^T.
    Let u_min be the minimum eigenvector of G.
    Let U = V Sigma Q^T and take v_min, q_min corresponding to the smallest singular value.
    Then D_beta = u_min q_min^T.
    Define B = u_min v_min^T + v_min u_min^T, and E = A^* A(B).
    Then D_gamma = E U.
    """

    d, r = U.shape

    # Matrix-space gradient.
    G = matrix_gradient_G(U, X, y)

    # Minimum eigenpair of G.
    eigvals, eigvecs = np.linalg.eigh(G)
    idx_min = np.argmin(eigvals)
    lambda_min = eigvals[idx_min]
    u_min = eigvecs[:, idx_min:idx_min + 1]

    # SVD of U.  U = V diag(S) QT
    V, S, QT = np.linalg.svd(U, full_matrices=False)

    # Smallest singular direction.
    v_min = V[:, -1:]
    q_min = QT.T[:, -1:]
    sigma_min = S[-1]

    # Beta direction.
    D_beta = u_min @ q_min.T

    # Gamma direction.
    B = u_min @ v_min.T + v_min @ u_min.T
    E = AstarA(B, X)
    D_gamma = E @ U

    if normalize:
        D_beta_norm = np.linalg.norm(D_beta, ord="fro")
        D_gamma_norm = np.linalg.norm(D_gamma, ord="fro")
        D_beta = D_beta / (D_beta_norm + 1e-12)
        D_gamma = D_gamma / (D_gamma_norm + 1e-12)

    return {"D_beta": D_beta, "D_gamma": D_gamma,
            "lambda_min": lambda_min, "sigma_min": sigma_min,
            "u_min": u_min, "v_min": v_min, "q_min": q_min,
            "G": G, "E": E,}

# %% [markdown]
# ### Functional helper for line-search methods

# %%
def make_symmetric_log_grid(min_exp=-6, max_exp=2, points_per_decade=3,):
    """
    Make symmetric logarithmic line-search grid.

    Example:
        positive grid roughly contains:
            1e-6, 2.15e-6, 4.64e-6, ..., 1e2

    Returns both positive and negative values.
    """

    num = (max_exp - min_exp) * points_per_decade + 1
    positive = np.logspace(min_exp, max_exp, num=num)
    #grid = np.concatenate([positive, -positive])
    #return grid
    return positive

def line_search_along_directions(U, X, y, directions, 
                                 direction_names=None, alpha_grid=None, relative_to_U=True, weight_decay=0.0,):
    """
    Generic deterministic line-search over a list of directions.
    Candidate: U_candidate = U + alpha * scale * D
    where scale = max(||U||_F, 1e-3) if relative_to_U is True.
    """

    if alpha_grid is None:
        alpha_grid = make_symmetric_log_grid(min_exp=-6, max_exp=2, points_per_decade=3,)

    if direction_names is None:
        direction_names = [f"dir_{k}" for k in range(len(directions))]

    current_loss = loss(U, X, y, weight_decay=weight_decay)

    scale = max(np.linalg.norm(U, ord="fro"), 1e-3) if relative_to_U else 1.0

    best_U = U.copy()
    best_loss = current_loss
    best_direction = "none"
    best_alpha = 0.0

    for name, D in zip(direction_names, directions):
        D_norm = np.linalg.norm(D, ord="fro")
        if D_norm < 1e-14:
            continue

        for alpha in alpha_grid:
            step = alpha * scale
            U_candidate = U + step * D
            val = loss(U_candidate, X, y, weight_decay=weight_decay)

            if val < best_loss:
                best_loss = val
                best_U = U_candidate.copy()
                best_direction = name
                best_alpha = step

    return {
        "best_U": best_U, "best_loss": best_loss, "best_direction": best_direction, "best_alpha": best_alpha,
        "current_loss": current_loss, "accepted": best_loss < current_loss,
    }

def sod_line_search(U, X, y, alpha_grid=None, relative_to_U=True, weight_decay=0.0, use_beta=True, use_gamma=True,):
    """
    SOD-guided structured line-search.
    Uses D_beta and/or D_gamma.
    """

    sod_info = sod_directions(U, X, y, normalize=True)

    directions = []
    names = []

    if use_beta:
        directions.append(sod_info["D_beta"])
        names.append("SOD-beta")
        
    if use_gamma:
        directions.append(sod_info["D_gamma"])
        names.append("SOD-gamma")

    ls_result = line_search_along_directions(U=U, X=X, y=y, directions=directions, direction_names=names,
                                             alpha_grid=alpha_grid, relative_to_U=relative_to_U, weight_decay=weight_decay,)

    ls_result.update({"lambda_min": sod_info["lambda_min"], "sigma_min": sod_info["sigma_min"],})

    return ls_result

# %% [markdown]
# ### Functional helpers for training

# %%
# Training loop with stall detection and SOD-LS
def train_quadratic_network(X_train, y_train, X_test, y_test, 
                            r=1, max_iters=10000, lr_dict=None, init_scale=1e-2, 
                            seed=0, weight_decay=0.0, method="gd_sod", batch_size=16,
                            adam_beta1=0.9, adam_beta2=0.999, adam_eps=1e-8,
                            stall_window=200, stall_tol=1e-6, min_iters_before_sod=500, sod_cooldown=200, accept_tol=1e-12,
                            alpha_min_exp=-6, alpha_max_exp=2, alpha_points_per_decade=3,):
    """
    Train one-hidden-layer quadratic network.

    method options:
        "gd":      full-batch gradient descent.
        "gd_sod":  full-batch gradient descent + SOD line-search when stalled.
        "sgd":     mini-batch stochastic gradient descent.
        "adam":    mini-batch Adam.
    """

    rng = np.random.default_rng(seed)
    N, d = X_train.shape
    assert lr_dict is not None
    # Initialize U.
    U = init_scale * rng.normal(size=(d, r))
    alpha_grid = make_symmetric_log_grid(min_exp=alpha_min_exp, max_exp=alpha_max_exp,
                                         points_per_decade=alpha_points_per_decade,)

    train_losses = []
    test_losses = []
    train_accs = []
    test_accs = []
    event_log = []

    last_sod_iter = -10**12

    # Adam states
    adam_m = np.zeros_like(U)
    adam_v = np.zeros_like(U)

    for t in range(max_iters + 1):
        train_loss_t = loss(U, X_train, y_train, weight_decay=weight_decay)
        test_loss_t = loss(U, X_test, y_test, weight_decay=0.0)

        train_losses.append(train_loss_t)
        test_losses.append(test_loss_t)
        train_accs.append(accuracy(U, X_train, y_train))
        test_accs.append(accuracy(U, X_test, y_test))

        if t % max(1, max_iters // 100) == 0:
            print(
                f"[{method}] iter={t:6d} "
                f"train_loss={train_loss_t:.6e} "
                f"test_loss={test_loss_t:.6e} "
                f"train_acc={train_accs[-1]:.3f} "
                f"test_acc={test_accs[-1]:.3f}"
            )

        if t == max_iters:
            break

        # ------------------------------------------------------------
        # Parameter update
        # ------------------------------------------------------------
        if method in ["gd", "gd_sod"]:
            # Full-batch GD update.
            g = grad_U(U, X_train, y_train, weight_decay=weight_decay)
            U = U - lr_dict[method] * g

        elif method == "sgd":
            # Mini-batch SGD update.
            actual_batch_size = min(batch_size, N)
            batch_idx = rng.choice(N, size=actual_batch_size, replace=False)
            g = grad_U_batch(U, X_train, y_train, batch_idx=batch_idx, weight_decay=weight_decay,)
            U = U - lr_dict[method] * g

        elif method == "adam":
            # Mini-batch Adam update.
            actual_batch_size = min(batch_size, N)
            batch_idx = rng.choice(N, size=actual_batch_size, replace=False)
            g = grad_U_batch(U, X_train, y_train, batch_idx=batch_idx, weight_decay=weight_decay,)
            adam_m = adam_beta1 * adam_m + (1.0 - adam_beta1) * g
            adam_v = adam_beta2 * adam_v + (1.0 - adam_beta2) * (g ** 2)
            # Bias correction
            adam_m_hat = adam_m / (1.0 - adam_beta1 ** (t + 1))
            adam_v_hat = adam_v / (1.0 - adam_beta2 ** (t + 1))
            U = U - lr_dict[method] * adam_m_hat / (np.sqrt(adam_v_hat) + adam_eps)

        else:
            raise ValueError("method must be one of 'gd', 'gd_sod', 'sgd', 'adam'.")

        # ------------------------------------------------------------
        # Stall detection and SOD line-search.
        # Only gd_sod uses this part.
        # ------------------------------------------------------------
        should_check_stall = (method == "gd_sod" and t >= min_iters_before_sod
                              and t >= stall_window and t - last_sod_iter >= sod_cooldown)

        if should_check_stall:
            old_loss = train_losses[-stall_window]
            new_loss = train_losses[-1]
            relative_drop = (old_loss - new_loss) / max(old_loss, 1e-12)

            if relative_drop < stall_tol:
                before_loss = loss(U, X_train, y_train, weight_decay=weight_decay)

                ls_result = sod_line_search(U=U, X=X_train, y=y_train,
                                            alpha_grid=alpha_grid, relative_to_U=True, weight_decay=weight_decay,
                                            use_beta=True, use_gamma=True,)

                after_loss = ls_result["best_loss"]
                improvement = before_loss - after_loss

                accepted = improvement > accept_tol

                event = {
                    "iter": t,
                    "method": method,
                    "relative_drop_window": relative_drop,
                    "before_loss": before_loss,
                    "after_loss": after_loss,
                    "improvement": improvement,
                    "accepted": accepted,
                    "direction": ls_result["best_direction"],
                    "alpha": ls_result["best_alpha"],
                    "lambda_min": ls_result["lambda_min"],
                    "sigma_min": ls_result["sigma_min"],
                }

                event_log.append(event)

                if accepted:
                    U = ls_result["best_U"]
                    last_sod_iter = t

                    print("-" * 80)
                    print(f"Stall detected at iter={t}. "
                          f"window_relative_drop={relative_drop:.3e}")
                    print(f"Line-search method={method}, "
                          f"direction={ls_result['best_direction']}, "
                          f"alpha={ls_result['best_alpha']:.3e}")
                    print(f"before_loss={before_loss:.6e}, "
                          f"after_loss={after_loss:.6e}, "
                          f"improvement={improvement:.6e}, "
                          f"accepted={accepted}")
                    print(f"lambda_min(G)={ls_result['lambda_min']:.6e}, "
                          f"sigma_min(U)={ls_result['sigma_min']:.6e}")
                    print("-" * 80)

    result = {
        "U": U,
        "train_losses": np.array(train_losses),
        "test_losses": np.array(test_losses),
        "train_accs": np.array(train_accs),
        "test_accs": np.array(test_accs),
        "event_log": event_log,
        "final_train_loss": train_losses[-1],
        "final_test_loss": test_losses[-1],
        "final_train_acc": train_accs[-1],
        "final_test_acc": test_accs[-1],
        "method": method,
        "r": r,
        "seed": seed,
    }

    return result

# %% [markdown]
# ### Run simulation

# %%
if args.method == "compare":
    methods = ["gd", "gd_sod", "sgd", "adam"]
    methods_color = {"gd": "blue", "gd_sod": "green", "sgd": "orange", "adam": "red"}
    methods_zorder = {"gd": 2, "gd_sod": 3, "sgd": 1, "adam": 0}
    methods_lr = args.lr_dict
else:
    methods = [args.method]
    methods_zorder = {args.method: 0}
    methods_color = {args.method: "red"}
    methods_lr = {args.method: args.lr_dict[args.method]}

results = []

for method in methods:
    print("\n" + "#" * 100)
    print(f"Running method: {method}")
    print("#" * 100)

    res = train_quadratic_network(
        X_train=X_train,
        y_train=y_train,
        X_test=X_test,
        y_test=y_test,
        r=args.r,
        max_iters=args.max_iters,
        lr_dict=methods_lr,
        init_scale=args.init_scale,
        seed=args.seed,
        weight_decay=args.weight_decay,
        method=method,
        # SGD / Adam parameters
        batch_size=args.batch_size,
        adam_beta1=args.adam_beta1,
        adam_beta2=args.adam_beta2,
        adam_eps=args.adam_eps,
        # SOD parameters
        stall_window=args.stall_window,
        stall_tol=args.stall_tol,
        min_iters_before_sod=args.min_iters_before_sod,
        sod_cooldown=args.sod_cooldown,
        accept_tol=args.accept_tol,
        alpha_min_exp=args.alpha_min_exp,
        alpha_max_exp=args.alpha_max_exp,
        alpha_points_per_decade=args.alpha_points_per_decade,
    )

    results.append(res)
# Out:
# ####################################################################################################
# Running method: gd
# ####################################################################################################
# [gd] iter=     0 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd] iter=   150 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd] iter=   300 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd] iter=   450 train_loss=2.495440e-01 test_loss=2.493079e-01 train_acc=0.500 test_acc=0.500
# [gd] iter=   600 train_loss=1.131806e-01 test_loss=9.283289e-02 train_acc=0.700 test_acc=0.800
# [gd] iter=   750 train_loss=4.794735e-02 test_loss=5.234757e-02 train_acc=0.860 test_acc=0.900
# [gd] iter=   900 train_loss=3.459068e-02 test_loss=4.283485e-02 train_acc=0.920 test_acc=0.940
# [gd] iter=  1050 train_loss=3.328241e-02 test_loss=4.055350e-02 train_acc=0.940 test_acc=0.940
# [gd] iter=  1200 train_loss=3.278738e-02 test_loss=3.977452e-02 train_acc=0.940 test_acc=0.960
# [gd] iter=  1350 train_loss=3.251705e-02 test_loss=3.951596e-02 train_acc=0.940 test_acc=0.960
# [gd] iter=  1500 train_loss=3.236339e-02 test_loss=3.945089e-02 train_acc=0.940 test_acc=0.960
# [gd] iter=  1650 train_loss=3.227500e-02 test_loss=3.946181e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  1800 train_loss=3.222383e-02 test_loss=3.950071e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  1950 train_loss=3.219407e-02 test_loss=3.954667e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2100 train_loss=3.217670e-02 test_loss=3.959069e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2250 train_loss=3.216655e-02 test_loss=3.962934e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2400 train_loss=3.216060e-02 test_loss=3.966174e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2550 train_loss=3.215710e-02 test_loss=3.968818e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2700 train_loss=3.215505e-02 test_loss=3.970938e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  2850 train_loss=3.215384e-02 test_loss=3.972617e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3000 train_loss=3.215313e-02 test_loss=3.973937e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3150 train_loss=3.215272e-02 test_loss=3.974968e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3300 train_loss=3.215247e-02 test_loss=3.975770e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3450 train_loss=3.215233e-02 test_loss=3.976392e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3600 train_loss=3.215224e-02 test_loss=3.976873e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3750 train_loss=3.215219e-02 test_loss=3.977244e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  3900 train_loss=3.215216e-02 test_loss=3.977531e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4050 train_loss=3.215214e-02 test_loss=3.977752e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4200 train_loss=3.215213e-02 test_loss=3.977922e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4350 train_loss=3.215213e-02 test_loss=3.978052e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4500 train_loss=3.215212e-02 test_loss=3.978153e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4650 train_loss=3.215212e-02 test_loss=3.978230e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4800 train_loss=3.215212e-02 test_loss=3.978290e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  4950 train_loss=3.215212e-02 test_loss=3.978335e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5100 train_loss=3.215212e-02 test_loss=3.978370e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5250 train_loss=3.215212e-02 test_loss=3.978397e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5400 train_loss=3.215212e-02 test_loss=3.978418e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5550 train_loss=3.215212e-02 test_loss=3.978434e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5700 train_loss=3.215212e-02 test_loss=3.978446e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  5850 train_loss=3.215212e-02 test_loss=3.978456e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6000 train_loss=3.215212e-02 test_loss=3.978463e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6150 train_loss=3.215212e-02 test_loss=3.978468e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6300 train_loss=3.215212e-02 test_loss=3.978473e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6450 train_loss=3.215212e-02 test_loss=3.978476e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6600 train_loss=3.215212e-02 test_loss=3.978478e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6750 train_loss=3.215212e-02 test_loss=3.978480e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  6900 train_loss=3.215212e-02 test_loss=3.978482e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7050 train_loss=3.215212e-02 test_loss=3.978483e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7200 train_loss=3.215212e-02 test_loss=3.978484e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7350 train_loss=3.215212e-02 test_loss=3.978484e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7500 train_loss=3.215212e-02 test_loss=3.978485e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7650 train_loss=3.215212e-02 test_loss=3.978485e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7800 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  7950 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8100 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8250 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8400 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8550 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8700 train_loss=3.215212e-02 test_loss=3.978486e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  8850 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9000 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9150 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9300 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9450 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9600 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9750 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter=  9900 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10050 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10200 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10350 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10500 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10650 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10800 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 10950 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11100 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11250 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11400 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11550 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11700 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 11850 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12000 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12150 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12300 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12450 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12600 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12750 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 12900 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13050 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13200 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13350 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13500 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13650 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13800 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 13950 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14100 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14250 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14400 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14550 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14700 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 14850 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
# [gd] iter= 15000 train_loss=3.215212e-02 test_loss=3.978487e-02 train_acc=0.920 test_acc=0.960
#
# ####################################################################################################
# Running method: gd_sod
# ####################################################################################################
# [gd_sod] iter=     0 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd_sod] iter=   150 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd_sod] iter=   300 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [gd_sod] iter=   450 train_loss=2.495440e-01 test_loss=2.493079e-01 train_acc=0.500 test_acc=0.500
# [gd_sod] iter=   600 train_loss=1.131806e-01 test_loss=9.283289e-02 train_acc=0.700 test_acc=0.800
# [gd_sod] iter=   750 train_loss=4.794735e-02 test_loss=5.234757e-02 train_acc=0.860 test_acc=0.900
# [gd_sod] iter=   900 train_loss=3.459068e-02 test_loss=4.283485e-02 train_acc=0.920 test_acc=0.940
# [gd_sod] iter=  1050 train_loss=3.328241e-02 test_loss=4.055350e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  1200 train_loss=3.278738e-02 test_loss=3.977452e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  1350 train_loss=3.251705e-02 test_loss=3.951596e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  1500 train_loss=3.236339e-02 test_loss=3.945089e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  1650 train_loss=3.227500e-02 test_loss=3.946181e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  1800 train_loss=3.222383e-02 test_loss=3.950071e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  1950 train_loss=3.219407e-02 test_loss=3.954667e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2100 train_loss=3.217670e-02 test_loss=3.959069e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2250 train_loss=3.216655e-02 test_loss=3.962934e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2400 train_loss=3.216060e-02 test_loss=3.966174e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2550 train_loss=3.215710e-02 test_loss=3.968818e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2700 train_loss=3.215505e-02 test_loss=3.970938e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  2850 train_loss=3.215384e-02 test_loss=3.972617e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3000 train_loss=3.215313e-02 test_loss=3.973937e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3150 train_loss=3.215272e-02 test_loss=3.974968e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3300 train_loss=3.215247e-02 test_loss=3.975770e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3450 train_loss=3.215233e-02 test_loss=3.976392e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3600 train_loss=3.215224e-02 test_loss=3.976873e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3750 train_loss=3.215219e-02 test_loss=3.977244e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  3900 train_loss=3.215216e-02 test_loss=3.977531e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  4050 train_loss=3.215214e-02 test_loss=3.977752e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  4200 train_loss=3.215213e-02 test_loss=3.977922e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  4350 train_loss=3.215213e-02 test_loss=3.978052e-02 train_acc=0.920 test_acc=0.960
# [gd_sod] iter=  4500 train_loss=3.215212e-02 test_loss=3.978153e-02 train_acc=0.920 test_acc=0.960
# --------------------------------------------------------------------------------
# Stall detected at iter=4639. window_relative_drop=9.978e-08
# Line-search method=gd_sod, direction=SOD-beta, alpha=4.191e-01
# before_loss=3.215212e-02, after_loss=3.060907e-02, improvement=1.543052e-03, accepted=True
# lambda_min(G)=-1.822325e-02, sigma_min(U)=7.928189e-07
# --------------------------------------------------------------------------------
# [gd_sod] iter=  4650 train_loss=3.012017e-02 test_loss=4.136728e-02 train_acc=0.960 test_acc=0.960
# [gd_sod] iter=  4800 train_loss=2.969790e-02 test_loss=3.926639e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  4950 train_loss=2.959967e-02 test_loss=3.934555e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  5100 train_loss=2.950942e-02 test_loss=3.943169e-02 train_acc=0.940 test_acc=0.960
# [gd_sod] iter=  5250 train_loss=2.942479e-02 test_loss=3.949564e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  5400 train_loss=2.934544e-02 test_loss=3.954823e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  5550 train_loss=2.927122e-02 test_loss=3.959552e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  5700 train_loss=2.920209e-02 test_loss=3.964030e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  5850 train_loss=2.913798e-02 test_loss=3.968388e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6000 train_loss=2.907882e-02 test_loss=3.972690e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6150 train_loss=2.902448e-02 test_loss=3.976969e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6300 train_loss=2.897479e-02 test_loss=3.981237e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6450 train_loss=2.892957e-02 test_loss=3.985497e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6600 train_loss=2.888858e-02 test_loss=3.989743e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6750 train_loss=2.885158e-02 test_loss=3.993967e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  6900 train_loss=2.881831e-02 test_loss=3.998153e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7050 train_loss=2.878850e-02 test_loss=4.002290e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7200 train_loss=2.876188e-02 test_loss=4.006360e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7350 train_loss=2.873817e-02 test_loss=4.010350e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7500 train_loss=2.871713e-02 test_loss=4.014246e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7650 train_loss=2.869850e-02 test_loss=4.018034e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7800 train_loss=2.868204e-02 test_loss=4.021704e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  7950 train_loss=2.866754e-02 test_loss=4.025246e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8100 train_loss=2.865480e-02 test_loss=4.028653e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8250 train_loss=2.864361e-02 test_loss=4.031919e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8400 train_loss=2.863381e-02 test_loss=4.035039e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8550 train_loss=2.862524e-02 test_loss=4.038012e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8700 train_loss=2.861776e-02 test_loss=4.040835e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  8850 train_loss=2.861124e-02 test_loss=4.043510e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9000 train_loss=2.860556e-02 test_loss=4.046038e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9150 train_loss=2.860063e-02 test_loss=4.048421e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9300 train_loss=2.859634e-02 test_loss=4.050664e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9450 train_loss=2.859262e-02 test_loss=4.052769e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9600 train_loss=2.858940e-02 test_loss=4.054742e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9750 train_loss=2.858660e-02 test_loss=4.056589e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter=  9900 train_loss=2.858419e-02 test_loss=4.058313e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10050 train_loss=2.858210e-02 test_loss=4.059922e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10200 train_loss=2.858030e-02 test_loss=4.061421e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10350 train_loss=2.857874e-02 test_loss=4.062816e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10500 train_loss=2.857739e-02 test_loss=4.064112e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10650 train_loss=2.857623e-02 test_loss=4.065316e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10800 train_loss=2.857524e-02 test_loss=4.066433e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 10950 train_loss=2.857437e-02 test_loss=4.067468e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11100 train_loss=2.857363e-02 test_loss=4.068427e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11250 train_loss=2.857300e-02 test_loss=4.069315e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11400 train_loss=2.857245e-02 test_loss=4.070136e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11550 train_loss=2.857197e-02 test_loss=4.070896e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11700 train_loss=2.857157e-02 test_loss=4.071598e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 11850 train_loss=2.857122e-02 test_loss=4.072246e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12000 train_loss=2.857092e-02 test_loss=4.072845e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12150 train_loss=2.857066e-02 test_loss=4.073398e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12300 train_loss=2.857044e-02 test_loss=4.073908e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12450 train_loss=2.857025e-02 test_loss=4.074379e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12600 train_loss=2.857009e-02 test_loss=4.074814e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12750 train_loss=2.856995e-02 test_loss=4.075214e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 12900 train_loss=2.856983e-02 test_loss=4.075584e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13050 train_loss=2.856972e-02 test_loss=4.075925e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13200 train_loss=2.856963e-02 test_loss=4.076239e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13350 train_loss=2.856956e-02 test_loss=4.076529e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13500 train_loss=2.856949e-02 test_loss=4.076796e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13650 train_loss=2.856944e-02 test_loss=4.077043e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13800 train_loss=2.856939e-02 test_loss=4.077270e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 13950 train_loss=2.856935e-02 test_loss=4.077479e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14100 train_loss=2.856931e-02 test_loss=4.077672e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14250 train_loss=2.856928e-02 test_loss=4.077850e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14400 train_loss=2.856926e-02 test_loss=4.078014e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14550 train_loss=2.856923e-02 test_loss=4.078166e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14700 train_loss=2.856921e-02 test_loss=4.078305e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 14850 train_loss=2.856920e-02 test_loss=4.078434e-02 train_acc=0.940 test_acc=0.940
# [gd_sod] iter= 15000 train_loss=2.856918e-02 test_loss=4.078553e-02 train_acc=0.940 test_acc=0.940
#
# ####################################################################################################
# Running method: sgd
# ####################################################################################################
# [sgd] iter=     0 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   150 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   300 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   450 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   600 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   750 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=   900 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1050 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1200 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1350 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1500 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1650 train_loss=2.499998e-01 test_loss=2.499997e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1800 train_loss=2.499986e-01 test_loss=2.499979e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  1950 train_loss=2.499884e-01 test_loss=2.499824e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  2100 train_loss=2.498995e-01 test_loss=2.498462e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  2250 train_loss=2.493051e-01 test_loss=2.489454e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  2400 train_loss=2.449036e-01 test_loss=2.422689e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  2550 train_loss=2.164787e-01 test_loss=1.996885e-01 train_acc=0.500 test_acc=0.500
# [sgd] iter=  2700 train_loss=1.636811e-01 test_loss=1.290167e-01 train_acc=0.580 test_acc=0.620
# [sgd] iter=  2850 train_loss=1.305696e-01 test_loss=1.023749e-01 train_acc=0.640 test_acc=0.740
# [sgd] iter=  3000 train_loss=1.085982e-01 test_loss=8.879388e-02 train_acc=0.720 test_acc=0.800
# [sgd] iter=  3150 train_loss=9.196787e-02 test_loss=7.829253e-02 train_acc=0.760 test_acc=0.800
# [sgd] iter=  3300 train_loss=7.712223e-02 test_loss=7.217680e-02 train_acc=0.780 test_acc=0.820
# [sgd] iter=  3450 train_loss=6.479930e-02 test_loss=6.281888e-02 train_acc=0.780 test_acc=0.860
# [sgd] iter=  3600 train_loss=5.415515e-02 test_loss=5.566173e-02 train_acc=0.820 test_acc=0.880
# [sgd] iter=  3750 train_loss=4.722707e-02 test_loss=5.327506e-02 train_acc=0.860 test_acc=0.900
# [sgd] iter=  3900 train_loss=4.192702e-02 test_loss=4.812856e-02 train_acc=0.860 test_acc=0.920
# [sgd] iter=  4050 train_loss=3.801859e-02 test_loss=4.689505e-02 train_acc=0.900 test_acc=0.920
# [sgd] iter=  4200 train_loss=3.637647e-02 test_loss=4.516551e-02 train_acc=0.940 test_acc=0.920
# [sgd] iter=  4350 train_loss=3.507803e-02 test_loss=4.292674e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  4500 train_loss=3.454918e-02 test_loss=4.292956e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  4650 train_loss=3.408726e-02 test_loss=4.228034e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  4800 train_loss=3.376179e-02 test_loss=4.177772e-02 train_acc=0.940 test_acc=0.940
# [sgd] iter=  4950 train_loss=3.357460e-02 test_loss=4.156821e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  5100 train_loss=3.339893e-02 test_loss=4.054138e-02 train_acc=0.940 test_acc=0.940
# [sgd] iter=  5250 train_loss=3.326610e-02 test_loss=3.968953e-02 train_acc=0.940 test_acc=0.940
# [sgd] iter=  5400 train_loss=3.313317e-02 test_loss=4.032608e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  5550 train_loss=3.309564e-02 test_loss=3.990919e-02 train_acc=0.940 test_acc=0.940
# [sgd] iter=  5700 train_loss=3.298912e-02 test_loss=4.005993e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  5850 train_loss=3.292812e-02 test_loss=4.053687e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6000 train_loss=3.277124e-02 test_loss=3.981554e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6150 train_loss=3.268846e-02 test_loss=3.931693e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6300 train_loss=3.261017e-02 test_loss=3.952148e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6450 train_loss=3.253196e-02 test_loss=3.918612e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6600 train_loss=3.249613e-02 test_loss=3.967613e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6750 train_loss=3.248403e-02 test_loss=3.928179e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  6900 train_loss=3.243687e-02 test_loss=3.936450e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  7050 train_loss=3.243092e-02 test_loss=3.895894e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  7200 train_loss=3.241296e-02 test_loss=3.856332e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  7350 train_loss=3.238246e-02 test_loss=3.965908e-02 train_acc=0.940 test_acc=0.940
# [sgd] iter=  7500 train_loss=3.237710e-02 test_loss=4.015670e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  7650 train_loss=3.229723e-02 test_loss=3.926862e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  7800 train_loss=3.231485e-02 test_loss=3.961125e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  7950 train_loss=3.227958e-02 test_loss=3.890112e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  8100 train_loss=3.232384e-02 test_loss=4.000689e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  8250 train_loss=3.230591e-02 test_loss=3.950382e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  8400 train_loss=3.228973e-02 test_loss=3.908817e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  8550 train_loss=3.228618e-02 test_loss=3.955427e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  8700 train_loss=3.225924e-02 test_loss=3.937476e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  8850 train_loss=3.232329e-02 test_loss=4.058324e-02 train_acc=0.960 test_acc=0.960
# [sgd] iter=  9000 train_loss=3.221605e-02 test_loss=3.982265e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  9150 train_loss=3.223064e-02 test_loss=4.040539e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  9300 train_loss=3.221632e-02 test_loss=4.010213e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  9450 train_loss=3.219813e-02 test_loss=3.951933e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  9600 train_loss=3.223384e-02 test_loss=3.878697e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter=  9750 train_loss=3.220485e-02 test_loss=3.942492e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter=  9900 train_loss=3.222443e-02 test_loss=4.008385e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 10050 train_loss=3.221128e-02 test_loss=4.027237e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 10200 train_loss=3.219980e-02 test_loss=3.995998e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 10350 train_loss=3.220936e-02 test_loss=4.025022e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 10500 train_loss=3.223179e-02 test_loss=3.921534e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 10650 train_loss=3.219556e-02 test_loss=3.920680e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 10800 train_loss=3.220140e-02 test_loss=3.998851e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 10950 train_loss=3.219449e-02 test_loss=3.963895e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 11100 train_loss=3.219349e-02 test_loss=3.988244e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 11250 train_loss=3.228945e-02 test_loss=4.053431e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 11400 train_loss=3.221094e-02 test_loss=3.972163e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 11550 train_loss=3.217459e-02 test_loss=3.942216e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 11700 train_loss=3.217871e-02 test_loss=3.972432e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 11850 train_loss=3.224268e-02 test_loss=3.976471e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 12000 train_loss=3.217529e-02 test_loss=3.963625e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 12150 train_loss=3.219929e-02 test_loss=4.059300e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 12300 train_loss=3.216656e-02 test_loss=3.989931e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 12450 train_loss=3.217437e-02 test_loss=4.035865e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 12600 train_loss=3.217144e-02 test_loss=3.991876e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 12750 train_loss=3.230335e-02 test_loss=4.052479e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 12900 train_loss=3.216869e-02 test_loss=3.963078e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13050 train_loss=3.216557e-02 test_loss=3.960762e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13200 train_loss=3.218711e-02 test_loss=3.929515e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13350 train_loss=3.217095e-02 test_loss=3.978347e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13500 train_loss=3.216624e-02 test_loss=4.018587e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13650 train_loss=3.217476e-02 test_loss=4.045609e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13800 train_loss=3.217977e-02 test_loss=4.062371e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 13950 train_loss=3.220638e-02 test_loss=4.064420e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 14100 train_loss=3.218752e-02 test_loss=4.053056e-02 train_acc=0.940 test_acc=0.960
# [sgd] iter= 14250 train_loss=3.225521e-02 test_loss=3.904619e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 14400 train_loss=3.218984e-02 test_loss=4.004663e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 14550 train_loss=3.226526e-02 test_loss=3.886522e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 14700 train_loss=3.223215e-02 test_loss=3.906345e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 14850 train_loss=3.220134e-02 test_loss=3.939314e-02 train_acc=0.920 test_acc=0.960
# [sgd] iter= 15000 train_loss=3.220725e-02 test_loss=3.974489e-02 train_acc=0.920 test_acc=0.960
#
# ####################################################################################################
# Running method: adam
# ####################################################################################################
# [adam] iter=     0 train_loss=2.500000e-01 test_loss=2.500000e-01 train_acc=0.500 test_acc=0.500
# [adam] iter=   150 train_loss=7.770109e-02 test_loss=7.127426e-02 train_acc=0.780 test_acc=0.820
# [adam] iter=   300 train_loss=3.518726e-02 test_loss=4.377564e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=   450 train_loss=3.267906e-02 test_loss=3.926810e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=   600 train_loss=3.326205e-02 test_loss=4.396304e-02 train_acc=0.960 test_acc=0.960
# [adam] iter=   750 train_loss=3.241552e-02 test_loss=3.947501e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=   900 train_loss=3.257533e-02 test_loss=3.843201e-02 train_acc=0.960 test_acc=0.980
# [adam] iter=  1050 train_loss=3.242787e-02 test_loss=3.899066e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  1200 train_loss=3.287094e-02 test_loss=4.420065e-02 train_acc=0.960 test_acc=0.980
# [adam] iter=  1350 train_loss=3.306676e-02 test_loss=3.946913e-02 train_acc=0.920 test_acc=0.920
# [adam] iter=  1500 train_loss=3.251962e-02 test_loss=4.017056e-02 train_acc=0.940 test_acc=0.980
# [adam] iter=  1650 train_loss=3.237026e-02 test_loss=3.821838e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  1800 train_loss=3.232333e-02 test_loss=4.088984e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  1950 train_loss=3.252436e-02 test_loss=3.810442e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=  2100 train_loss=3.258272e-02 test_loss=4.300729e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  2250 train_loss=3.276321e-02 test_loss=3.731583e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=  2400 train_loss=3.243563e-02 test_loss=4.192389e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  2550 train_loss=3.235125e-02 test_loss=4.072001e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=  2700 train_loss=3.246358e-02 test_loss=4.324700e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  2850 train_loss=3.240972e-02 test_loss=4.162253e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  3000 train_loss=3.239131e-02 test_loss=4.187628e-02 train_acc=0.940 test_acc=0.940
# [adam] iter=  3150 train_loss=3.319068e-02 test_loss=4.709502e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  3300 train_loss=3.291143e-02 test_loss=4.307114e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  3450 train_loss=3.245436e-02 test_loss=4.123501e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  3600 train_loss=3.369690e-02 test_loss=3.945670e-02 train_acc=0.920 test_acc=0.920
# [adam] iter=  3750 train_loss=3.318759e-02 test_loss=3.879234e-02 train_acc=0.920 test_acc=0.920
# [adam] iter=  3900 train_loss=3.234278e-02 test_loss=3.968230e-02 train_acc=0.940 test_acc=0.980
# [adam] iter=  4050 train_loss=3.276284e-02 test_loss=4.150082e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  4200 train_loss=3.235331e-02 test_loss=4.144490e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  4350 train_loss=3.242111e-02 test_loss=3.746992e-02 train_acc=0.920 test_acc=0.980
# [adam] iter=  4500 train_loss=3.242438e-02 test_loss=4.144567e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  4650 train_loss=3.229687e-02 test_loss=4.139485e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  4800 train_loss=3.238484e-02 test_loss=4.194537e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  4950 train_loss=3.228458e-02 test_loss=3.852712e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  5100 train_loss=3.233761e-02 test_loss=4.004794e-02 train_acc=0.920 test_acc=0.920
# [adam] iter=  5250 train_loss=3.237290e-02 test_loss=3.780518e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  5400 train_loss=3.274596e-02 test_loss=4.200606e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  5550 train_loss=3.265483e-02 test_loss=3.996818e-02 train_acc=0.940 test_acc=0.940
# [adam] iter=  5700 train_loss=3.229303e-02 test_loss=3.923293e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  5850 train_loss=3.224343e-02 test_loss=4.100639e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  6000 train_loss=3.251200e-02 test_loss=3.745720e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  6150 train_loss=3.227887e-02 test_loss=3.878515e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  6300 train_loss=3.247097e-02 test_loss=3.905732e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=  6450 train_loss=3.238585e-02 test_loss=4.150984e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  6600 train_loss=3.287354e-02 test_loss=4.401808e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  6750 train_loss=3.237596e-02 test_loss=3.771013e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  6900 train_loss=3.241656e-02 test_loss=3.969108e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  7050 train_loss=3.227874e-02 test_loss=4.076310e-02 train_acc=0.920 test_acc=0.940
# [adam] iter=  7200 train_loss=3.247003e-02 test_loss=3.962812e-02 train_acc=0.960 test_acc=0.980
# [adam] iter=  7350 train_loss=3.267864e-02 test_loss=4.092369e-02 train_acc=0.920 test_acc=0.920
# [adam] iter=  7500 train_loss=3.221199e-02 test_loss=3.841034e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  7650 train_loss=3.220089e-02 test_loss=3.919885e-02 train_acc=0.920 test_acc=0.960
# [adam] iter=  7800 train_loss=3.240999e-02 test_loss=4.197796e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  7950 train_loss=3.220547e-02 test_loss=3.723038e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  8100 train_loss=3.225389e-02 test_loss=4.151499e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  8250 train_loss=3.233643e-02 test_loss=3.798200e-02 train_acc=0.940 test_acc=0.980
# [adam] iter=  8400 train_loss=3.212095e-02 test_loss=3.752293e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  8550 train_loss=3.193156e-02 test_loss=4.145796e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  8700 train_loss=3.211834e-02 test_loss=4.250988e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  8850 train_loss=3.267758e-02 test_loss=4.515034e-02 train_acc=0.960 test_acc=0.960
# [adam] iter=  9000 train_loss=3.156036e-02 test_loss=4.147319e-02 train_acc=0.940 test_acc=0.940
# [adam] iter=  9150 train_loss=3.129577e-02 test_loss=4.003398e-02 train_acc=0.940 test_acc=0.940
# [adam] iter=  9300 train_loss=3.117767e-02 test_loss=3.847707e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  9450 train_loss=3.086624e-02 test_loss=4.060543e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  9600 train_loss=3.063550e-02 test_loss=4.019622e-02 train_acc=0.940 test_acc=0.960
# [adam] iter=  9750 train_loss=3.153817e-02 test_loss=3.683285e-02 train_acc=0.940 test_acc=0.940
# [adam] iter=  9900 train_loss=2.989239e-02 test_loss=3.884323e-02 train_acc=0.940 test_acc=0.960
# [adam] iter= 10050 train_loss=3.051428e-02 test_loss=4.483054e-02 train_acc=0.940 test_acc=0.960
# [adam] iter= 10200 train_loss=2.951714e-02 test_loss=3.962545e-02 train_acc=0.940 test_acc=0.960
# [adam] iter= 10350 train_loss=2.937193e-02 test_loss=4.046598e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 10500 train_loss=2.935836e-02 test_loss=3.839540e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 10650 train_loss=2.898164e-02 test_loss=3.969542e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 10800 train_loss=2.889148e-02 test_loss=4.103539e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 10950 train_loss=2.881921e-02 test_loss=4.074423e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 11100 train_loss=2.903344e-02 test_loss=4.255742e-02 train_acc=0.940 test_acc=0.960
# [adam] iter= 11250 train_loss=2.894456e-02 test_loss=4.023051e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 11400 train_loss=2.893087e-02 test_loss=3.965197e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 11550 train_loss=2.897549e-02 test_loss=4.002223e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 11700 train_loss=2.875188e-02 test_loss=4.151995e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 11850 train_loss=2.912900e-02 test_loss=4.307952e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12000 train_loss=2.863977e-02 test_loss=4.055402e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12150 train_loss=2.909397e-02 test_loss=4.394269e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12300 train_loss=2.866475e-02 test_loss=4.179810e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12450 train_loss=2.917333e-02 test_loss=4.243353e-02 train_acc=0.940 test_acc=0.960
# [adam] iter= 12600 train_loss=2.871690e-02 test_loss=3.947246e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12750 train_loss=2.880668e-02 test_loss=4.251376e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 12900 train_loss=2.876832e-02 test_loss=4.170562e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13050 train_loss=2.915694e-02 test_loss=3.852209e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13200 train_loss=2.888762e-02 test_loss=4.210390e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13350 train_loss=2.887876e-02 test_loss=4.386968e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13500 train_loss=2.925391e-02 test_loss=3.906066e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13650 train_loss=2.867980e-02 test_loss=4.179014e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13800 train_loss=2.867591e-02 test_loss=4.195488e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 13950 train_loss=2.927063e-02 test_loss=4.201448e-02 train_acc=0.920 test_acc=0.940
# [adam] iter= 14100 train_loss=2.884002e-02 test_loss=3.873928e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 14250 train_loss=2.886260e-02 test_loss=3.978985e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 14400 train_loss=2.866615e-02 test_loss=4.122226e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 14550 train_loss=2.906604e-02 test_loss=3.953018e-02 train_acc=0.940 test_acc=0.940
# [adam] iter= 14700 train_loss=2.918387e-02 test_loss=4.059251e-02 train_acc=0.920 test_acc=0.940
# [adam] iter= 14850 train_loss=2.892606e-02 test_loss=3.958374e-02 train_acc=0.920 test_acc=0.940
# [adam] iter= 15000 train_loss=2.871617e-02 test_loss=4.098665e-02 train_acc=0.940 test_acc=0.940

# %% [markdown]
# ### Visualize the results

# %%
fig0, (ax00, ax01) = plt.subplots(1, 2, figsize=(14, 4), gridspec_kw=dict(width_ratios=[1.0, 1.0]))

for res in results:
    train_losses = res["train_losses"]
    test_losses = res["test_losses"]
    method = res["method"]
    seed = res["seed"]
#     print(train_losses.shape)
#     ax00.semilogy(train_losses, label=f"{method}, seed={seed}", linewidth=2)
#     ax01.semilogy(test_losses, label=f"{method}, seed={seed}", linewidth=2)
#     ax00.semilogy(train_losses[:12000], label=f"{method}", linewidth=2)
#     ax01.semilogy(test_losses[:12000], label=f"{method}", linewidth=2)
    ax00.semilogy(train_losses, label=f"{method}", linewidth=2, 
                  color=methods_color[method], zorder=methods_zorder[method])
    ax01.semilogy(test_losses, label=f"{method}", linewidth=2, 
                  color=methods_color[method], zorder=methods_zorder[method])
    
    # Mark accepted events.
    for ev in res["event_log"]:
        if ev["accepted"]:
            ax00.axvline(ev["iter"], color="#4B0082", alpha=0.8, linestyle="--", linewidth=2, label="SOD-Escape")
            ax01.axvline(ev["iter"], color="#4B0082", alpha=0.8, linestyle="--", linewidth=2, label="SOD-Escape")

ax00.set_xlabel("Iteration", fontsize=14)
ax00.set_ylabel("Training Loss", fontsize=14)
ax00.grid(True, alpha=0.25, linestyle="--")
#ax00.set_ylim(0.4, 1)
ax00.set_xlim(0, args.max_iters)
ax00.legend(loc="upper right", frameon=True, fontsize=14)
ax00.tick_params(axis='both', labelsize=14)
ax00.set_title("Training Loss Curves", fontsize=14)

ax01.set_xlabel("Iteration", fontsize=14)
ax01.set_ylabel("Testing Loss", fontsize=14)
ax01.grid(True, alpha=0.25, linestyle="--")
#ax01.set_ylim(0.4, 1)
ax01.set_xlim(0, args.max_iters)
ax01.legend(loc="upper right", frameon=True, fontsize=14)
ax01.tick_params(axis='both', labelsize=14)
ax01.set_title("Testing Loss Curves", fontsize=14) 

fig0.tight_layout()
plt.show()
fig0.savefig("quadratic_nn_optimizer_loss.pdf", dpi=300, format="pdf", bbox_inches="tight")
print(f"Saved figure to: quadratic_nn_optimizer_loss.pdf")
# Out:
# Saved figure to: quadratic_nn_optimizer_loss.pdf

# %%
fig1, (ax10, ax11) = plt.subplots(1, 2, figsize=(14, 4), gridspec_kw=dict(width_ratios=[1.0, 1.0]))

for res in results:
    method = res["method"]
    seed = res["seed"]

#     ax10.plot(res["train_accs"], label=f"{method}, seed={seed}, train", linewidth=2,)
#     ax11.plot(res["test_accs"], label=f"{method}, seed={seed}, test", linewidth=2,)
    ax10.plot(res["train_accs"], label=f"{method}", linewidth=2, 
              color=methods_color[method], zorder=methods_zorder[method])
    ax11.plot(res["test_accs"], label=f"{method}", linewidth=2, 
              color=methods_color[method], zorder=methods_zorder[method])
    
    # Mark accepted events.
    for ev in res["event_log"]:
        if ev["accepted"]:
            ax10.axvline(ev["iter"], color="#4B0082", alpha=0.8, linestyle="--", linewidth=2, label="SOD-Escape")
            ax11.axvline(ev["iter"], color="#4B0082", alpha=0.8, linestyle="--", linewidth=2, label="SOD-Escape")

ax10.set_xlabel("Iteration", fontsize=14)
ax10.set_ylabel("Training Accuracy", fontsize=14)
ax10.grid(True, alpha=0.25, linestyle="--")
ax10.set_ylim(0.4, 1)
ax10.set_xlim(0, args.max_iters)
ax10.legend(loc="lower right", frameon=True, fontsize=14)
ax10.tick_params(axis='both', labelsize=14)
ax10.set_title("Training Accuracy Curves", fontsize=14)

ax11.set_xlabel("Iteration", fontsize=14)
ax11.set_ylabel("Testing Accuracy", fontsize=14)
ax11.grid(True, alpha=0.25, linestyle="--")
ax11.set_ylim(0.4, 1)
ax11.set_xlim(0, args.max_iters)
ax11.legend(loc="lower right", frameon=True, fontsize=14)
ax11.tick_params(axis='both', labelsize=14)
ax11.set_title("Testing Accuracy Curves", fontsize=14) 

fig1.tight_layout()
plt.show()
fig1.savefig("quadratic_nn_optimizer_accuracy.pdf", dpi=300, format="pdf", bbox_inches="tight")
print(f"Saved figure to: quadratic_nn_optimizer_accuracy.pdf")
# Out:
# Saved figure to: quadratic_nn_optimizer_accuracy.pdf
